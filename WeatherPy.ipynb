# %%
#Retrieve weather data
# 1) Create set of 2000 random latitude and longitudes
# 2) Get the nearest city using citipy module
# 3) Perform an API call with the OpenWeatherMap
# 4) Retrieve the following information from the API Call:
#     Latitude and longitude
#     Maximum temperature
#     Percent humidity
#     Percent cloudiness
#     Wind speed
#     Weather description (for example, clouds, fog, light rain, clear sky)
# 5) Add data to a new DataFrame
# 6) Export the DataFrame as a CSV file
# 7) Save CSV as WeatherPy_Database.csv in Weather_Database folder

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint

# %%
# Redirect print statements from terminal to Jupyter Notebook.
import sys
stdout = sys.stdout

# some functions that mess up sys.stdout

sys.stdout = stdout

# %%
#  Use the citipy module to  determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the request library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module form the datime library
import time
from datetime import datetime

# %%
# Create a set of random latitudes and longitudes combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and a longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Loop through the cities list.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
city = ()
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ea0e53b2e429e62c9e7a57981a870810

# %%
# Create an empty list to hold the weatherdata.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | forestville
# Processing Record 6 of Set 1 | gibsons
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pundaguitan
# Processing Record 10 of Set 1 | omboue
# Processing Record 11 of Set 1 | manaure
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | damaturu
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | ulladulla
# Processing Record 17 of Set 1 | kinsale
# Processing Record 18 of Set 1 | gushikawa
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | havoysund
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | wanaka
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | leh
# Processing Record 27 of Set 1 | lavrentiya
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | ngunguru
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | marzuq
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | vestmanna
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao felix do xingu
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | constantine
# Processing Record 43 of Set 1 | carballo
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | mindelo
# Processing Record 49 of Set 1 | ucluelet
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | iqaluit
# Processing Record 2 of Set 2 | bambanglipuro
# Processing Record 3 of Set 2 | namibe
# Processing Record 4 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 2 | mitsamiouli
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 2 | nanortalik
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | verkhoyansk
# Processing Record 14 of Set 2 | luangwa
# Processing Record 15 of Set 2 | maceio
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | kabo
# Processing Record 25 of Set 2 | havelock
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | pacifica
# Processing Record 28 of Set 2 | puerto escondido
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | xai-xai
# Processing Record 31 of Set 2 | rognan
# Processing Record 32 of Set 2 | port hardy
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | manyana
# Processing Record 35 of Set 2 | bowen
# Processing Record 36 of Set 2 | avera
# Processing Record 37 of Set 2 | raga
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | mahibadhoo
# Processing Record 40 of Set 2 | zhigansk
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | mudu
# Processing Record 43 of Set 2 | aklavik
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | zhaocheng
# City not found. Skipping...
# Processing Record 46 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | wanning
# Processing Record 50 of Set 2 | yugorsk
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | sena madureira
# Processing Record 3 of Set 3 | urubicha
# Processing Record 4 of Set 3 | santa maria
# Processing Record 5 of Set 3 | cockburn town
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | bontang
# Processing Record 8 of Set 3 | ukiah
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | comodoro rivadavia
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | makinsk
# Processing Record 13 of Set 3 | sorong
# Processing Record 14 of Set 3 | flinders
# Processing Record 15 of Set 3 | huitziltepec
# Processing Record 16 of Set 3 | kutum
# Processing Record 17 of Set 3 | ubatuba
# Processing Record 18 of Set 3 | naze
# Processing Record 19 of Set 3 | burica
# City not found. Skipping...
# Processing Record 20 of Set 3 | holbeach
# Processing Record 21 of Set 3 | nyurba
# Processing Record 22 of Set 3 | taksimo
# Processing Record 23 of Set 3 | port hedland
# Processing Record 24 of Set 3 | mozarlandia
# Processing Record 25 of Set 3 | tongliao
# Processing Record 26 of Set 3 | nishihara
# Processing Record 27 of Set 3 | nemuro
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | willowmore
# Processing Record 30 of Set 3 | aberdeen
# Processing Record 31 of Set 3 | monrovia
# Processing Record 32 of Set 3 | castlegar
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | aksu
# Processing Record 36 of Set 3 | pangnirtung
# Processing Record 37 of Set 3 | ontario
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | valdivia
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | santa
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | viedma
# Processing Record 44 of Set 3 | brandenburg
# Processing Record 45 of Set 3 | faranah
# Processing Record 46 of Set 3 | la plaine
# Processing Record 47 of Set 3 | hokitika
# Processing Record 48 of Set 3 | faya
# Processing Record 49 of Set 3 | mount pleasant
# Processing Record 50 of Set 3 | bangaon
# Processing Record 1 of Set 4 | salvador
# Processing Record 2 of Set 4 | rio grande
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | cape town
# Processing Record 5 of Set 4 | coracora
# Processing Record 6 of Set 4 | ishigaki
# Processing Record 7 of Set 4 | lahij
# Processing Record 8 of Set 4 | kuching
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | jardim
# Processing Record 11 of Set 4 | flin flon
# Processing Record 12 of Set 4 | ostersund
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | fare
# Processing Record 15 of Set 4 | madingou
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | ambilobe
# Processing Record 18 of Set 4 | tommot
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | saint-francois
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 4 | skjervoy
# Processing Record 24 of Set 4 | ayagoz
# Processing Record 25 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 4 | honiara
# Processing Record 27 of Set 4 | caraballeda
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | kapaa
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | pimentel
# Processing Record 33 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 4 | mombetsu
# Processing Record 35 of Set 4 | eydhafushi
# Processing Record 36 of Set 4 | bairiki
# Processing Record 37 of Set 4 | san andres
# Processing Record 38 of Set 4 | aksarka
# Processing Record 39 of Set 4 | koumac
# Processing Record 40 of Set 4 | mossendjo
# Processing Record 41 of Set 4 | kosgi
# City not found. Skipping...
# Processing Record 42 of Set 4 | rio gallegos
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | okhotsk
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | szedres
# Processing Record 50 of Set 4 | kieta
# Processing Record 1 of Set 5 | birao
# Processing Record 2 of Set 5 | kamenka
# Processing Record 3 of Set 5 | fairbanks
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | lakes entrance
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | cabra
# Processing Record 10 of Set 5 | richards bay
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | culaba
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | salalah
# Processing Record 16 of Set 5 | sibolga
# Processing Record 17 of Set 5 | redcar
# Processing Record 18 of Set 5 | sikonge
# Processing Record 19 of Set 5 | bonavista
# Processing Record 20 of Set 5 | maniitsoq
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | kampot
# Processing Record 23 of Set 5 | omsukchan
# Processing Record 24 of Set 5 | muravlenko
# Processing Record 25 of Set 5 | enid
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | puerto ayacucho
# Processing Record 28 of Set 5 | ambon
# Processing Record 29 of Set 5 | bogotol
# Processing Record 30 of Set 5 | bilma
# Processing Record 31 of Set 5 | novyy urgal
# Processing Record 32 of Set 5 | grand gaube
# Processing Record 33 of Set 5 | bom jesus
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | tongchuan
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | pisco
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | kenai
# Processing Record 42 of Set 5 | macklin
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | paamiut
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | nova olimpia
# Processing Record 47 of Set 5 | yellowknife
# Processing Record 48 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 5 | bam
# Processing Record 50 of Set 5 | lubbock
# Processing Record 1 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 6 | abu samrah
# Processing Record 3 of Set 6 | yuzhno-kurilsk
# Processing Record 4 of Set 6 | machala
# Processing Record 5 of Set 6 | laguna
# Processing Record 6 of Set 6 | pangkalanbuun
# Processing Record 7 of Set 6 | chalisgaon
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | nouadhibou
# Processing Record 11 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | raudeberg
# Processing Record 15 of Set 6 | puerto leguizamo
# Processing Record 16 of Set 6 | la ronge
# Processing Record 17 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 6 | fort nelson
# Processing Record 19 of Set 6 | hervey bay
# Processing Record 20 of Set 6 | dzilam gonzalez
# Processing Record 21 of Set 6 | vao
# Processing Record 22 of Set 6 | doha
# Processing Record 23 of Set 6 | veshenskaya
# Processing Record 24 of Set 6 | bondo
# Processing Record 25 of Set 6 | miedzyrzecz
# Processing Record 26 of Set 6 | prince rupert
# Processing Record 27 of Set 6 | chupaca
# Processing Record 28 of Set 6 | maltahohe
# Processing Record 29 of Set 6 | caravelas
# Processing Record 30 of Set 6 | carnarvon
# Processing Record 31 of Set 6 | clovis
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | besikduzu
# Processing Record 34 of Set 6 | ewa beach
# Processing Record 35 of Set 6 | kumluca
# Processing Record 36 of Set 6 | benguela
# Processing Record 37 of Set 6 | guasdualito
# Processing Record 38 of Set 6 | norman wells
# Processing Record 39 of Set 6 | oksfjord
# Processing Record 40 of Set 6 | kirakira
# Processing Record 41 of Set 6 | kambove
# Processing Record 42 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 6 | diu
# Processing Record 44 of Set 6 | nikolskoye
# Processing Record 45 of Set 6 | kailua
# Processing Record 46 of Set 6 | aktau
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | altay
# Processing Record 50 of Set 6 | manaus
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | iskilip
# Processing Record 3 of Set 7 | hithadhoo
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | mount isa
# Processing Record 6 of Set 7 | sorland
# Processing Record 7 of Set 7 | tual
# Processing Record 8 of Set 7 | cortez
# Processing Record 9 of Set 7 | russell
# Processing Record 10 of Set 7 | senaki
# Processing Record 11 of Set 7 | selma
# Processing Record 12 of Set 7 | kalmunai
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | port-cartier
# Processing Record 15 of Set 7 | la trinidad
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | barra do garcas
# Processing Record 18 of Set 7 | yenagoa
# Processing Record 19 of Set 7 | hinton
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | consett
# Processing Record 22 of Set 7 | korla
# Processing Record 23 of Set 7 | surt
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | sao jose da coroa grande
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 7 | sumbe
# Processing Record 29 of Set 7 | tessalit
# Processing Record 30 of Set 7 | anqing
# Processing Record 31 of Set 7 | semibratovo
# Processing Record 32 of Set 7 | quatre cocos
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | ponferrada
# Processing Record 35 of Set 7 | amarante do maranhao
# Processing Record 36 of Set 7 | komsomolskiy
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | aasiaat
# Processing Record 39 of Set 7 | hovd
# Processing Record 40 of Set 7 | sangar
# Processing Record 41 of Set 7 | cervo
# Processing Record 42 of Set 7 | coahuayana
# Processing Record 43 of Set 7 | vanavara
# Processing Record 44 of Set 7 | rundu
# Processing Record 45 of Set 7 | dali
# Processing Record 46 of Set 7 | phetchaburi
# Processing Record 47 of Set 7 | seoul
# Processing Record 48 of Set 7 | enshi
# Processing Record 49 of Set 7 | fez
# Processing Record 50 of Set 7 | pacific grove
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | road town
# Processing Record 3 of Set 8 | taungdwingyi
# Processing Record 4 of Set 8 | emba
# Processing Record 5 of Set 8 | lorengau
# Processing Record 6 of Set 8 | panzhihua
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | buribay
# Processing Record 9 of Set 8 | bayonet point
# Processing Record 10 of Set 8 | aras
# Processing Record 11 of Set 8 | venado tuerto
# Processing Record 12 of Set 8 | half moon bay
# Processing Record 13 of Set 8 | ukholovo
# Processing Record 14 of Set 8 | lavumisa
# Processing Record 15 of Set 8 | saint-augustin
# Processing Record 16 of Set 8 | tuktoyaktuk
# Processing Record 17 of Set 8 | kahului
# Processing Record 18 of Set 8 | bethel
# Processing Record 19 of Set 8 | kruisfontein
# Processing Record 20 of Set 8 | shaunavon
# Processing Record 21 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | saint-joseph
# Processing Record 23 of Set 8 | hanzhong
# Processing Record 24 of Set 8 | tahta
# Processing Record 25 of Set 8 | giyani
# Processing Record 26 of Set 8 | palmer
# Processing Record 27 of Set 8 | graaff-reinet
# Processing Record 28 of Set 8 | turukhansk
# Processing Record 29 of Set 8 | concordia
# Processing Record 30 of Set 8 | whitehorse
# Processing Record 31 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 8 | voh
# Processing Record 33 of Set 8 | moron
# Processing Record 34 of Set 8 | sindor
# Processing Record 35 of Set 8 | bluefield
# Processing Record 36 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 8 | chegutu
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | davila
# Processing Record 40 of Set 8 | fillan
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | jumla
# Processing Record 43 of Set 8 | wageningen
# Processing Record 44 of Set 8 | agadez
# Processing Record 45 of Set 8 | dejen
# Processing Record 46 of Set 8 | ouango
# Processing Record 47 of Set 8 | nanakuli
# Processing Record 48 of Set 8 | mount gambier
# Processing Record 49 of Set 8 | ketchikan
# Processing Record 50 of Set 8 | islamkot
# Processing Record 1 of Set 9 | baykit
# Processing Record 2 of Set 9 | verkhnevilyuysk
# Processing Record 3 of Set 9 | san cristobal
# Processing Record 4 of Set 9 | chuy
# Processing Record 5 of Set 9 | dargaville
# Processing Record 6 of Set 9 | voznesenye
# Processing Record 7 of Set 9 | tura
# Processing Record 8 of Set 9 | henties bay
# Processing Record 9 of Set 9 | kashi
# Processing Record 10 of Set 9 | kupang
# Processing Record 11 of Set 9 | touros
# Processing Record 12 of Set 9 | ulaangom
# Processing Record 13 of Set 9 | bubaque
# Processing Record 14 of Set 9 | lashio
# Processing Record 15 of Set 9 | newport
# Processing Record 16 of Set 9 | newark
# Processing Record 17 of Set 9 | yablonovo
# Processing Record 18 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | aykhal
# Processing Record 21 of Set 9 | serta
# Processing Record 22 of Set 9 | coos bay
# Processing Record 23 of Set 9 | yei
# Processing Record 24 of Set 9 | mazamitla
# Processing Record 25 of Set 9 | leo
# Processing Record 26 of Set 9 | puerto carreno
# Processing Record 27 of Set 9 | fangshan
# Processing Record 28 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 29 of Set 9 | dzhebariki-khaya
# Processing Record 30 of Set 9 | illapel
# Processing Record 31 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 9 | antissa
# City not found. Skipping...
# Processing Record 33 of Set 9 | rebrikha
# Processing Record 34 of Set 9 | bandarbeyla
# Processing Record 35 of Set 9 | hede
# Processing Record 36 of Set 9 | brigantine
# Processing Record 37 of Set 9 | haines junction
# Processing Record 38 of Set 9 | nicoya
# Processing Record 39 of Set 9 | atar
# Processing Record 40 of Set 9 | clyde river
# Processing Record 41 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 9 | vazante
# Processing Record 43 of Set 9 | leticia
# Processing Record 44 of Set 9 | san juan
# Processing Record 45 of Set 9 | tabriz
# Processing Record 46 of Set 9 | bathsheba
# Processing Record 47 of Set 9 | vangaindrano
# Processing Record 48 of Set 9 | tomatlan
# Processing Record 49 of Set 9 | minsk
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | banjar
# Processing Record 2 of Set 10 | sakakah
# Processing Record 3 of Set 10 | san vicente
# Processing Record 4 of Set 10 | arona
# Processing Record 5 of Set 10 | amga
# Processing Record 6 of Set 10 | dhule
# Processing Record 7 of Set 10 | goderich
# Processing Record 8 of Set 10 | smithers
# Processing Record 9 of Set 10 | antalaha
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | kungurtug
# Processing Record 12 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 10 | kautokeino
# Processing Record 15 of Set 10 | faanui
# Processing Record 16 of Set 10 | rock springs
# Processing Record 17 of Set 10 | kulhudhuffushi
# Processing Record 18 of Set 10 | nevelsk
# Processing Record 19 of Set 10 | misratah
# Processing Record 20 of Set 10 | itarema
# Processing Record 21 of Set 10 | martapura
# Processing Record 22 of Set 10 | minab
# Processing Record 23 of Set 10 | port keats
# Processing Record 24 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 10 | kondagaon
# Processing Record 26 of Set 10 | ammon
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | sistranda
# Processing Record 29 of Set 10 | waiuku
# Processing Record 30 of Set 10 | asau
# Processing Record 31 of Set 10 | ossora
# Processing Record 32 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 10 | kota
# Processing Record 34 of Set 10 | terney
# Processing Record 35 of Set 10 | bilibino
# Processing Record 36 of Set 10 | griffith
# Processing Record 37 of Set 10 | cotonou
# Processing Record 38 of Set 10 | nuuk
# Processing Record 39 of Set 10 | shenzhen
# Processing Record 40 of Set 10 | quang ngai
# Processing Record 41 of Set 10 | batagay-alyta
# Processing Record 42 of Set 10 | tiznit
# Processing Record 43 of Set 10 | vila do maio
# Processing Record 44 of Set 10 | cheney
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | soe
# Processing Record 47 of Set 10 | iskateley
# Processing Record 48 of Set 10 | eyl
# Processing Record 49 of Set 10 | yorkton
# Processing Record 50 of Set 10 | port victoria
# Processing Record 1 of Set 11 | ekhabi
# Processing Record 2 of Set 11 | baker city
# Processing Record 3 of Set 11 | kristiansund
# Processing Record 4 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 11 | beringovskiy
# Processing Record 6 of Set 11 | mayya
# Processing Record 7 of Set 11 | grand-santi
# Processing Record 8 of Set 11 | itaituba
# Processing Record 9 of Set 11 | ballyshannon
# Processing Record 10 of Set 11 | saint combs
# City not found. Skipping...
# Processing Record 11 of Set 11 | shihezi
# Processing Record 12 of Set 11 | nacogdoches
# Processing Record 13 of Set 11 | panguna
# Processing Record 14 of Set 11 | gotsu
# Processing Record 15 of Set 11 | noumea
# Processing Record 16 of Set 11 | saint paul
# Processing Record 17 of Set 11 | batagay
# Processing Record 18 of Set 11 | panino
# Processing Record 19 of Set 11 | muros
# Processing Record 20 of Set 11 | sao jose da tapera
# Processing Record 21 of Set 11 | zelenoborsk
# Processing Record 22 of Set 11 | provideniya
# Processing Record 23 of Set 11 | kushmurun
# Processing Record 24 of Set 11 | camden
# Processing Record 25 of Set 11 | moree
# Processing Record 26 of Set 11 | yarmouth
# Processing Record 27 of Set 11 | tigre
# Processing Record 28 of Set 11 | la rioja
# Processing Record 29 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 30 of Set 11 | srednekolymsk
# Processing Record 31 of Set 11 | belaya gora
# Processing Record 32 of Set 11 | saint-pierre
# Processing Record 33 of Set 11 | mayumba
# Processing Record 34 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 11 | albanel
# Processing Record 36 of Set 11 | algiers
# Processing Record 37 of Set 11 | lata
# Processing Record 38 of Set 11 | gao
# Processing Record 39 of Set 11 | plettenberg bay
# Processing Record 40 of Set 11 | dunedin
# Processing Record 41 of Set 11 | kulu
# Processing Record 42 of Set 11 | glace bay
# Processing Record 43 of Set 11 | burnie
# Processing Record 44 of Set 11 | velizh
# Processing Record 45 of Set 11 | termiz
# Processing Record 46 of Set 11 | calceta
# Processing Record 47 of Set 11 | merke
# Processing Record 48 of Set 11 | deputatskiy
# Processing Record 49 of Set 11 | north bend
# Processing Record 50 of Set 11 | camana
# Processing Record 1 of Set 12 | lagoa
# Processing Record 2 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 12 | katsuura
# Processing Record 4 of Set 12 | beyneu
# Processing Record 5 of Set 12 | auki
# Processing Record 6 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 7 of Set 12 | gorom-gorom
# Processing Record 8 of Set 12 | palanga
# Processing Record 9 of Set 12 | vidnoye
# Processing Record 10 of Set 12 | oskaloosa
# Processing Record 11 of Set 12 | biak
# Processing Record 12 of Set 12 | januaria
# Processing Record 13 of Set 12 | samarai
# Processing Record 14 of Set 12 | shumskiy
# Processing Record 15 of Set 12 | arman
# Processing Record 16 of Set 12 | aksarayskiy
# Processing Record 17 of Set 12 | tezu
# Processing Record 18 of Set 12 | jonesboro
# Processing Record 19 of Set 12 | nueve de julio
# Processing Record 20 of Set 12 | excelsior springs
# Processing Record 21 of Set 12 | neuquen
# Processing Record 22 of Set 12 | sao joao da barra
# Processing Record 23 of Set 12 | saint-fabien
# City not found. Skipping...
# Processing Record 24 of Set 12 | zalesovo
# Processing Record 25 of Set 12 | medea
# Processing Record 26 of Set 12 | porec
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | cozumel
# Processing Record 29 of Set 12 | pangody
# Processing Record 30 of Set 12 | nushki
# Processing Record 31 of Set 12 | riyadh
# Processing Record 32 of Set 12 | la trinitaria
# Processing Record 33 of Set 12 | chatrapur
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | kargasok
# Processing Record 36 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 12 | arara
# Processing Record 38 of Set 12 | natchitoches
# Processing Record 39 of Set 12 | ipixuna
# Processing Record 40 of Set 12 | floriano
# Processing Record 41 of Set 12 | phan thiet
# Processing Record 42 of Set 12 | seymchan
# Processing Record 43 of Set 12 | upata
# Processing Record 44 of Set 12 | esso
# Processing Record 45 of Set 12 | yuli
# Processing Record 46 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 47 of Set 12 | wanlaweyn
# Processing Record 48 of Set 12 | huarmey
# Processing Record 49 of Set 12 | mavelikara
# Processing Record 50 of Set 12 | savannah bight
# Processing Record 1 of Set 13 | vryburg
# Processing Record 2 of Set 13 | challapata
# Processing Record 3 of Set 13 | vallenar
# Processing Record 4 of Set 13 | kandiari
# Processing Record 5 of Set 13 | los dos caminos
# Processing Record 6 of Set 13 | bras-panon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
pprint.pprint(city_data)
# Out:
# [{'City': 'New Norfolk',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:27:34',
#   'Humidity': 79,
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 45.91,
#   'Wind Speed': 7},
#  {'City': 'Punta Arenas',
#   'Cloudiness': 75,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:27:34',
#   'Humidity': 66,
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.71,
#   'Wind Speed': 16.11},
#  {'City': 'Mataura',
#   'Cloudiness': 19,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:27:35',
#   'Humidity': 45,
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 71.55,
#   'Wind Speed': 0.96},
#  {'City': 'East London',
#   'Cloudiness': 100,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:27:35',
#   'Humidity': 96,
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 66.34,
#   'Wind Speed': 8.21},
#  {'City': 'Forestville',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:27:36',
#   'Humidity': 80,
#   'Lat': 38.8451,
#   'Lng': -76.875,
#   'Max Temp': 61.3,
#   'Wind Speed': 9.22},
#  {'City': 'Gibsons',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:27:36',
#   'Humidity': 91,
#   'Lat': 49.3997,
#   'Lng': -123.5027,
#   'Max Temp': 49.08,
#   'Wind Speed': 5.88},
#  {'City': 'Barrow',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:23:09',
#   'Humidity': 86,
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 21.22,
#   'Wind Speed': 10.36},
#  {'City': 'Rikitea',
#   'Cloudiness': 25,
#   'Country': 'PF',
#   'Date': '2021-10-29 01:24:13',
#   'Humidity': 78,
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.76,
#   'Wind Speed': 18.21},
#  {'City': 'Pundaguitan',
#   'Cloudiness': 100,
#   'Country': 'PH',
#   'Date': '2021-10-29 01:26:05',
#   'Humidity': 77,
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 82.78,
#   'Wind Speed': 9.73},
#  {'City': 'Omboue',
#   'Cloudiness': 62,
#   'Country': 'GA',
#   'Date': '2021-10-29 01:22:49',
#   'Humidity': 92,
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 75.36,
#   'Wind Speed': 5.77},
#  {'City': 'Manaure',
#   'Cloudiness': 99,
#   'Country': 'CO',
#   'Date': '2021-10-29 01:27:38',
#   'Humidity': 78,
#   'Lat': 11.7751,
#   'Lng': -72.4445,
#   'Max Temp': 82.36,
#   'Wind Speed': 3.11},
#  {'City': 'Codrington',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:27:38',
#   'Humidity': 59,
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 52.92,
#   'Wind Speed': 21.18},
#  {'City': 'Damaturu',
#   'Cloudiness': 100,
#   'Country': 'NG',
#   'Date': '2021-10-29 01:27:39',
#   'Humidity': 16,
#   'Lat': 11.747,
#   'Lng': 11.9608,
#   'Max Temp': 79.63,
#   'Wind Speed': 5.64},
#  {'City': 'Leningradskiy',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:27:39',
#   'Humidity': 89,
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 3.49,
#   'Wind Speed': 5.73},
#  {'City': 'Lebu',
#   'Cloudiness': 31,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:27:40',
#   'Humidity': 87,
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 52.79,
#   'Wind Speed': 14.92},
#  {'City': 'Ulladulla',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:27:40',
#   'Humidity': 33,
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 84.87,
#   'Wind Speed': 17.09},
#  {'City': 'Kinsale',
#   'Cloudiness': 75,
#   'Country': 'IE',
#   'Date': '2021-10-29 01:27:41',
#   'Humidity': 87,
#   'Lat': 51.7075,
#   'Lng': -8.5306,
#   'Max Temp': 51.17,
#   'Wind Speed': 8.05},
#  {'City': 'Gushikawa',
#   'Cloudiness': 1,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:27:41',
#   'Humidity': 50,
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 76.62,
#   'Wind Speed': 10.36},
#  {'City': 'Hobart',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:22:56',
#   'Humidity': 95,
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 46.26,
#   'Wind Speed': 3},
#  {'City': 'Souillac',
#   'Cloudiness': 20,
#   'Country': 'MU',
#   'Date': '2021-10-29 01:24:43',
#   'Humidity': 94,
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 74.35,
#   'Wind Speed': 6.91},
#  {'City': 'Khatanga',
#   'Cloudiness': 95,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:27:42',
#   'Humidity': 99,
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -14.93,
#   'Wind Speed': 7.25},
#  {'City': 'Havoysund',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': '2021-10-29 01:27:43',
#   'Humidity': 79,
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 38.28,
#   'Wind Speed': 28.54},
#  {'City': 'Jamestown',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:24:57',
#   'Humidity': 78,
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 56.52,
#   'Wind Speed': 8.01},
#  {'City': 'Wanaka',
#   'Cloudiness': 68,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:27:02',
#   'Humidity': 62,
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 64.11,
#   'Wind Speed': 5.01},
#  {'City': 'Mar Del Plata',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:27:44',
#   'Humidity': 91,
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 68.09,
#   'Wind Speed': 7},
#  {'City': 'Leh',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:27:44',
#   'Humidity': 59,
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 23.27,
#   'Wind Speed': 2.04},
#  {'City': 'Lavrentiya',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:25:25',
#   'Humidity': 87,
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 17.22,
#   'Wind Speed': 7.09},
#  {'City': 'Talnakh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:23:15',
#   'Humidity': 90,
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -3.32,
#   'Wind Speed': 9.48},
#  {'City': 'Sinnamary',
#   'Cloudiness': 100,
#   'Country': 'GF',
#   'Date': '2021-10-29 01:27:45',
#   'Humidity': 87,
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 78.85,
#   'Wind Speed': 9.31},
#  {'City': 'Ngunguru',
#   'Cloudiness': 100,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:27:46',
#   'Humidity': 60,
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 66.51,
#   'Wind Speed': 8.72},
#  {'City': 'Marzuq',
#   'Cloudiness': 5,
#   'Country': 'YE',
#   'Date': '2021-10-29 01:27:46',
#   'Humidity': 34,
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 68.56,
#   'Wind Speed': 1.28},
#  {'City': 'Bredasdorp',
#   'Cloudiness': 55,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:24:40',
#   'Humidity': 88,
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 60.12,
#   'Wind Speed': 1.14},
#  {'City': 'Esperance',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:27:47',
#   'Humidity': 65,
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 53.44,
#   'Wind Speed': 11.92},
#  {'City': 'Vestmanna',
#   'Cloudiness': 90,
#   'Country': 'FO',
#   'Date': '2021-10-29 01:24:36',
#   'Humidity': 100,
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 47.32,
#   'Wind Speed': 14.97},
#  {'City': 'Qaanaaq',
#   'Cloudiness': 85,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:27:48',
#   'Humidity': 82,
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 17.1,
#   'Wind Speed': 7.25},
#  {'City': 'Sao Felix Do Xingu',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:27:49',
#   'Humidity': 66,
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 78.15,
#   'Wind Speed': 2.37},
#  {'City': 'Bluff',
#   'Cloudiness': 15,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:27:49',
#   'Humidity': 75,
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 59.52,
#   'Wind Speed': 8.3},
#  {'City': 'Constantine',
#   'Cloudiness': 20,
#   'Country': 'DZ',
#   'Date': '2021-10-29 01:27:50',
#   'Humidity': 93,
#   'Lat': 36.365,
#   'Lng': 6.6147,
#   'Max Temp': 49.41,
#   'Wind Speed': 2.3},
#  {'City': 'Carballo',
#   'Cloudiness': 100,
#   'Country': 'ES',
#   'Date': '2021-10-29 01:27:50',
#   'Humidity': 93,
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 60.55,
#   'Wind Speed': 5.39},
#  {'City': 'Saint George',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:27:51',
#   'Humidity': 41,
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 69.94,
#   'Wind Speed': 1.99},
#  {'City': 'Castro',
#   'Cloudiness': 96,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:27:51',
#   'Humidity': 95,
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 60.98,
#   'Wind Speed': 7.27},
#  {'City': 'Saint-Philippe',
#   'Cloudiness': 41,
#   'Country': 'RE',
#   'Date': '2021-10-29 01:24:35',
#   'Humidity': 81,
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 72.99,
#   'Wind Speed': 5.75},
#  {'City': 'Atuona',
#   'Cloudiness': 4,
#   'Country': 'PF',
#   'Date': '2021-10-29 01:27:52',
#   'Humidity': 69,
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.26,
#   'Wind Speed': 16.37},
#  {'City': 'Mindelo',
#   'Cloudiness': 40,
#   'Country': 'CV',
#   'Date': '2021-10-29 01:23:12',
#   'Humidity': 73,
#   'Lat': 16.8901,
#   'Lng': -24.9804,
#   'Max Temp': 76.55,
#   'Wind Speed': 23.02},
#  {'City': 'Ucluelet',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:25:17',
#   'Humidity': 90,
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 49.08,
#   'Wind Speed': 5.44},
#  {'City': 'Georgetown',
#   'Cloudiness': 20,
#   'Country': 'MY',
#   'Date': '2021-10-29 01:27:53',
#   'Humidity': 86,
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82.33,
#   'Wind Speed': 3.44},
#  {'City': 'Iqaluit',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:25:55',
#   'Humidity': 75,
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 38.93,
#   'Wind Speed': 8.01},
#  {'City': 'Bambanglipuro',
#   'Cloudiness': 97,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:27:54',
#   'Humidity': 76,
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 82.6,
#   'Wind Speed': 3.27},
#  {'City': 'Namibe',
#   'Cloudiness': 30,
#   'Country': 'AO',
#   'Date': '2021-10-29 01:23:09',
#   'Humidity': 71,
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 66.51,
#   'Wind Speed': 5.84},
#  {'City': 'Mitsamiouli',
#   'Cloudiness': 10,
#   'Country': 'KM',
#   'Date': '2021-10-29 01:27:55',
#   'Humidity': 73,
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 78.48,
#   'Wind Speed': 14.03},
#  {'City': 'Ushuaia',
#   'Cloudiness': 20,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:27:55',
#   'Humidity': 47,
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 56.86,
#   'Wind Speed': 10.36},
#  {'City': 'Torbay',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:24:49',
#   'Humidity': 95,
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 39.58,
#   'Wind Speed': 16.11},
#  {'City': 'Nanortalik',
#   'Cloudiness': 76,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:23:27',
#   'Humidity': 72,
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 35.01,
#   'Wind Speed': 2.93},
#  {'City': 'Klaksvik',
#   'Cloudiness': 44,
#   'Country': 'FO',
#   'Date': '2021-10-29 01:24:28',
#   'Humidity': 88,
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 49.12,
#   'Wind Speed': 25.72},
#  {'City': 'Sitka',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': '2021-10-29 01:27:57',
#   'Humidity': 75,
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 42.69,
#   'Wind Speed': 9.22},
#  {'City': 'Verkhoyansk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:27:57',
#   'Humidity': 90,
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': 8.2,
#   'Wind Speed': 3.85},
#  {'City': 'Luangwa',
#   'Cloudiness': 2,
#   'Country': 'ZM',
#   'Date': '2021-10-29 01:27:58',
#   'Humidity': 64,
#   'Lat': -15.6167,
#   'Lng': 30.4167,
#   'Max Temp': 73.24,
#   'Wind Speed': 10.74},
#  {'City': 'Maceio',
#   'Cloudiness': 40,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:27:58',
#   'Humidity': 89,
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 80.04,
#   'Wind Speed': 5.75},
#  {'City': 'Port Blair',
#   'Cloudiness': 55,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:25:53',
#   'Humidity': 76,
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 82.33,
#   'Wind Speed': 11.23},
#  {'City': 'Tasiilaq',
#   'Cloudiness': 11,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:27:59',
#   'Humidity': 70,
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 30.36,
#   'Wind Speed': 8.23},
#  {'City': 'Cidreira',
#   'Cloudiness': 32,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:23:06',
#   'Humidity': 84,
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 68,
#   'Wind Speed': 17.27},
#  {'City': 'Kaitangata',
#   'Cloudiness': 77,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:28:00',
#   'Humidity': 72,
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 59.47,
#   'Wind Speed': 6.04},
#  {'City': 'Albany',
#   'Cloudiness': 13,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:00',
#   'Humidity': 90,
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 44.56,
#   'Wind Speed': 0.74},
#  {'City': 'Mehamn',
#   'Cloudiness': 90,
#   'Country': 'NO',
#   'Date': '2021-10-29 01:28:01',
#   'Humidity': 92,
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 34.92,
#   'Wind Speed': 15.82},
#  {'City': 'Isangel',
#   'Cloudiness': 75,
#   'Country': 'VU',
#   'Date': '2021-10-29 01:28:01',
#   'Humidity': 78,
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 82.51,
#   'Wind Speed': 11.5},
#  {'City': 'Hermanus',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:28:02',
#   'Humidity': 90,
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 59.9,
#   'Wind Speed': 10.2},
#  {'City': 'Kabo',
#   'Cloudiness': 100,
#   'Country': 'CF',
#   'Date': '2021-10-29 01:28:02',
#   'Humidity': 90,
#   'Lat': 7.6994,
#   'Lng': 18.629,
#   'Max Temp': 71.35,
#   'Wind Speed': 3.02},
#  {'City': 'Havelock',
#   'Cloudiness': 100,
#   'Country': 'US',
#   'Date': '2021-10-29 01:27:47',
#   'Humidity': 93,
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 68.02,
#   'Wind Speed': 5.01},
#  {'City': 'Vaini',
#   'Cloudiness': 75,
#   'Country': 'TO',
#   'Date': '2021-10-29 01:24:12',
#   'Humidity': 89,
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.96,
#   'Wind Speed': 13.8},
#  {'City': 'Pacifica',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': '2021-10-29 01:23:12',
#   'Humidity': 76,
#   'Lat': 37.6138,
#   'Lng': -122.4869,
#   'Max Temp': 75.2,
#   'Wind Speed': 1.01},
#  {'City': 'Puerto Escondido',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:28:03',
#   'Humidity': 61,
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 83.23,
#   'Wind Speed': 3.44},
#  {'City': 'Coquimbo',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:28:04',
#   'Humidity': 94,
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 55.13,
#   'Wind Speed': 3.44},
#  {'City': 'Xai-Xai',
#   'Cloudiness': 88,
#   'Country': 'MZ',
#   'Date': '2021-10-29 01:28:04',
#   'Humidity': 73,
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 63.05,
#   'Wind Speed': 4.83},
#  {'City': 'Rognan',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': '2021-10-29 01:28:05',
#   'Humidity': 91,
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 44.76,
#   'Wind Speed': 7.74},
#  {'City': 'Port Hardy',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:28:05',
#   'Humidity': 87,
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 48.2,
#   'Wind Speed': 5.75},
#  {'City': 'Butaritari',
#   'Cloudiness': 2,
#   'Country': 'KI',
#   'Date': '2021-10-29 01:28:05',
#   'Humidity': 68,
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.6,
#   'Wind Speed': 12.26},
#  {'City': 'Manyana',
#   'Cloudiness': 100,
#   'Country': 'BW',
#   'Date': '2021-10-29 01:28:06',
#   'Humidity': 82,
#   'Lat': -23.4,
#   'Lng': 21.7167,
#   'Max Temp': 65.61,
#   'Wind Speed': 7.49},
#  {'City': 'Bowen',
#   'Cloudiness': 0,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:28:06',
#   'Humidity': 59,
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 86.22,
#   'Wind Speed': 8.43},
#  {'City': 'Avera',
#   'Cloudiness': 6,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:07',
#   'Humidity': 90,
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 67.51,
#   'Wind Speed': 8.41},
#  {'City': 'Raga',
#   'Cloudiness': 88,
#   'Country': 'SS',
#   'Date': '2021-10-29 01:28:07',
#   'Humidity': 66,
#   'Lat': 8.4596,
#   'Lng': 25.678,
#   'Max Temp': 75.83,
#   'Wind Speed': 2.8},
#  {'City': 'Thompson',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:28:08',
#   'Humidity': 100,
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 39.36,
#   'Wind Speed': 8.05},
#  {'City': 'Mahibadhoo',
#   'Cloudiness': 87,
#   'Country': 'MV',
#   'Date': '2021-10-29 01:28:08',
#   'Humidity': 75,
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 82.31,
#   'Wind Speed': 10.38},
#  {'City': 'Zhigansk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:26:04',
#   'Humidity': 92,
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 12.61,
#   'Wind Speed': 9.33},
#  {'City': 'Avarua',
#   'Cloudiness': 90,
#   'Country': 'CK',
#   'Date': '2021-10-29 01:28:09',
#   'Humidity': 69,
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Wind Speed': 8.05},
#  {'City': 'Mudu',
#   'Cloudiness': 5,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:28:10',
#   'Humidity': 57,
#   'Lat': 31.252,
#   'Lng': 120.5118,
#   'Max Temp': 65.98,
#   'Wind Speed': 4.38},
#  {'City': 'Aklavik',
#   'Cloudiness': 95,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:23:39',
#   'Humidity': 96,
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 27.32,
#   'Wind Speed': 1.59},
#  {'City': 'Cabo San Lucas',
#   'Cloudiness': 1,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:25:06',
#   'Humidity': 66,
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 81.7,
#   'Wind Speed': 3},
#  {'City': 'Narsaq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:28:11',
#   'Humidity': 70,
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 30.42,
#   'Wind Speed': 4.9},
#  {'City': 'Busselton',
#   'Cloudiness': 24,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:28:12',
#   'Humidity': 56,
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.05,
#   'Wind Speed': 7.63},
#  {'City': 'Wanning',
#   'Cloudiness': 100,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:28:12',
#   'Humidity': 91,
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 76.82,
#   'Wind Speed': 11.36},
#  {'City': 'Yugorsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:12',
#   'Humidity': 85,
#   'Lat': 61.3133,
#   'Lng': 63.3319,
#   'Max Temp': 22.78,
#   'Wind Speed': 16.42},
#  {'City': 'Puerto Ayora',
#   'Cloudiness': 91,
#   'Country': 'EC',
#   'Date': '2021-10-29 01:24:00',
#   'Humidity': 93,
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.56,
#   'Wind Speed': 5.99},
#  {'City': 'Sena Madureira',
#   'Cloudiness': 29,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:28:13',
#   'Humidity': 98,
#   'Lat': -9.0656,
#   'Lng': -68.6569,
#   'Max Temp': 72.14,
#   'Wind Speed': 2.42},
#  {'City': 'Urubicha',
#   'Cloudiness': 100,
#   'Country': 'BO',
#   'Date': '2021-10-29 01:28:14',
#   'Humidity': 95,
#   'Lat': -15.3833,
#   'Lng': -62.95,
#   'Max Temp': 71.22,
#   'Wind Speed': 6.15},
#  {'City': 'Santa Maria',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:28:14',
#   'Humidity': 60,
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 70.9,
#   'Wind Speed': 8.05},
#  {'City': 'Cockburn Town',
#   'Cloudiness': 0,
#   'Country': 'TC',
#   'Date': '2021-10-29 01:28:15',
#   'Humidity': 71,
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.62,
#   'Wind Speed': 7.4},
#  {'City': 'Olafsvik',
#   'Cloudiness': 100,
#   'Country': 'IS',
#   'Date': '2021-10-29 01:24:46',
#   'Humidity': 93,
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 41.54,
#   'Wind Speed': 33.67},
#  {'City': 'Bontang',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:28:15',
#   'Humidity': 70,
#   'Lat': 0.1333,
#   'Lng': 117.5,
#   'Max Temp': 83.44,
#   'Wind Speed': 4.18},
#  {'City': 'Ukiah',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:16',
#   'Humidity': 60,
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp': 71.49,
#   'Wind Speed': 0},
#  {'City': 'Kodiak',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:16',
#   'Humidity': 48,
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 40.51,
#   'Wind Speed': 9.22},
#  {'City': 'Comodoro Rivadavia',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:28:17',
#   'Humidity': 36,
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 60.66,
#   'Wind Speed': 8.05},
#  {'City': 'Guerrero Negro',
#   'Cloudiness': 0,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:28:17',
#   'Humidity': 59,
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 71.35,
#   'Wind Speed': 10.92},
#  {'City': 'Makinsk',
#   'Cloudiness': 98,
#   'Country': 'KZ',
#   'Date': '2021-10-29 01:28:18',
#   'Humidity': 53,
#   'Lat': 52.6292,
#   'Lng': 70.4169,
#   'Max Temp': 22.53,
#   'Wind Speed': 17.13},
#  {'City': 'Sorong',
#   'Cloudiness': 91,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:24:35',
#   'Humidity': 74,
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 84.4,
#   'Wind Speed': 12.19},
#  {'City': 'Flinders',
#   'Cloudiness': 1,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:26:23',
#   'Humidity': 42,
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 88.21,
#   'Wind Speed': 11.99},
#  {'City': 'Huitziltepec',
#   'Cloudiness': 54,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:28:19',
#   'Humidity': 86,
#   'Lat': 17.8167,
#   'Lng': -99.4667,
#   'Max Temp': 65.86,
#   'Wind Speed': 4.36},
#  {'City': 'Kutum',
#   'Cloudiness': 13,
#   'Country': 'SD',
#   'Date': '2021-10-29 01:28:19',
#   'Humidity': 16,
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 69.71,
#   'Wind Speed': 9.04},
#  {'City': 'Ubatuba',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:26:02',
#   'Humidity': 95,
#   'Lat': -23.4339,
#   'Lng': -45.0711,
#   'Max Temp': 71.13,
#   'Wind Speed': 3.02},
#  {'City': 'Naze',
#   'Cloudiness': 97,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:24:48',
#   'Humidity': 57,
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 76.12,
#   'Wind Speed': 10.78},
#  {'City': 'Holbeach',
#   'Cloudiness': 100,
#   'Country': 'GB',
#   'Date': '2021-10-29 01:28:20',
#   'Humidity': 84,
#   'Lat': 52.804,
#   'Lng': 0.0144,
#   'Max Temp': 59.11,
#   'Wind Speed': 15.01},
#  {'City': 'Nyurba',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:21',
#   'Humidity': 70,
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 19.18,
#   'Wind Speed': 12.75},
#  {'City': 'Taksimo',
#   'Cloudiness': 35,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:21',
#   'Humidity': 64,
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 23.18,
#   'Wind Speed': 1.92},
#  {'City': 'Port Hedland',
#   'Cloudiness': 1,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:28:22',
#   'Humidity': 48,
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 86.05,
#   'Wind Speed': 9.22},
#  {'City': 'Mozarlandia',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:28:23',
#   'Humidity': 48,
#   'Lat': -14.7447,
#   'Lng': -50.5706,
#   'Max Temp': 83.93,
#   'Wind Speed': 1.52},
#  {'City': 'Tongliao',
#   'Cloudiness': 100,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:28:23',
#   'Humidity': 39,
#   'Lat': 43.6125,
#   'Lng': 122.2653,
#   'Max Temp': 51.73,
#   'Wind Speed': 10.49},
#  {'City': 'Nishihara',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:26:47',
#   'Humidity': 55,
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 76.68,
#   'Wind Speed': 9.22},
#  {'City': 'Nemuro',
#   'Cloudiness': 100,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:25:48',
#   'Humidity': 82,
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 48.63,
#   'Wind Speed': 26.8},
#  {'City': 'Longyearbyen',
#   'Cloudiness': 98,
#   'Country': 'SJ',
#   'Date': '2021-10-29 01:28:24',
#   'Humidity': 91,
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 16.93,
#   'Wind Speed': 5.26},
#  {'City': 'Willowmore',
#   'Cloudiness': 70,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:28:25',
#   'Humidity': 89,
#   'Lat': -33.2926,
#   'Lng': 23.4895,
#   'Max Temp': 59.45,
#   'Wind Speed': 5.53},
#  {'City': 'Aberdeen',
#   'Cloudiness': 90,
#   'Country': 'GB',
#   'Date': '2021-10-29 01:28:25',
#   'Humidity': 96,
#   'Lat': 57.1437,
#   'Lng': -2.0981,
#   'Max Temp': 52.29,
#   'Wind Speed': 5.75},
#  {'City': 'Monrovia',
#   'Cloudiness': 100,
#   'Country': 'LR',
#   'Date': '2021-10-29 01:28:25',
#   'Humidity': 86,
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 74.97,
#   'Wind Speed': 3.38},
#  {'City': 'Castlegar',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:28:26',
#   'Humidity': 100,
#   'Lat': 49.2998,
#   'Lng': -117.6689,
#   'Max Temp': 47.3,
#   'Wind Speed': 1.01},
#  {'City': 'Chokurdakh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:26',
#   'Humidity': 93,
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -4.13,
#   'Wind Speed': 3.51},
#  {'City': 'Pevek',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:23:32',
#   'Humidity': 94,
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 1.49,
#   'Wind Speed': 4.5},
#  {'City': 'Aksu',
#   'Cloudiness': 100,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:28:27',
#   'Humidity': 43,
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 46.38,
#   'Wind Speed': 2.66},
#  {'City': 'Pangnirtung',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:25:56',
#   'Humidity': 98,
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 29.16,
#   'Wind Speed': 3.56},
#  {'City': 'Ontario',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:26:28',
#   'Humidity': 31,
#   'Lat': 34.0633,
#   'Lng': -117.6509,
#   'Max Temp': 85.6,
#   'Wind Speed': 1.01},
#  {'City': 'Valdivia',
#   'Cloudiness': 24,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:28:28',
#   'Humidity': 96,
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 53.69,
#   'Wind Speed': 0.58},
#  {'City': 'Victoria',
#   'Cloudiness': 53,
#   'Country': 'HK',
#   'Date': '2021-10-29 01:26:27',
#   'Humidity': 78,
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 79.97,
#   'Wind Speed': 1.99},
#  {'City': 'Santa',
#   'Cloudiness': 15,
#   'Country': 'PH',
#   'Date': '2021-10-29 01:28:29',
#   'Humidity': 67,
#   'Lat': 17.486,
#   'Lng': 120.4348,
#   'Max Temp': 80.82,
#   'Wind Speed': 5.28},
#  {'City': 'Hilo',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': '2021-10-29 01:24:12',
#   'Humidity': 67,
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.13,
#   'Wind Speed': 8.05},
#  {'City': 'Viedma',
#   'Cloudiness': 100,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:25:18',
#   'Humidity': 44,
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 69.51,
#   'Wind Speed': 1.03},
#  {'City': 'Brandenburg',
#   'Cloudiness': 15,
#   'Country': 'DE',
#   'Date': '2021-10-29 01:28:30',
#   'Humidity': 77,
#   'Lat': 52.4167,
#   'Lng': 12.55,
#   'Max Temp': 46.99,
#   'Wind Speed': 7.09},
#  {'City': 'Faranah',
#   'Cloudiness': 100,
#   'Country': 'GN',
#   'Date': '2021-10-29 01:28:30',
#   'Humidity': 93,
#   'Lat': 10.0404,
#   'Lng': -10.7434,
#   'Max Temp': 71.44,
#   'Wind Speed': 3.8},
#  {'City': 'La Plaine',
#   'Cloudiness': 100,
#   'Country': 'DM',
#   'Date': '2021-10-29 01:28:31',
#   'Humidity': 76,
#   'Lat': 15.3333,
#   'Lng': -61.25,
#   'Max Temp': 78.93,
#   'Wind Speed': 7.74},
#  {'City': 'Hokitika',
#   'Cloudiness': 100,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:28:31',
#   'Humidity': 94,
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 54.54,
#   'Wind Speed': 1.9},
#  {'City': 'Faya',
#   'Cloudiness': 2,
#   'Country': 'SA',
#   'Date': '2021-10-29 01:24:52',
#   'Humidity': 52,
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 55.51,
#   'Wind Speed': 3.36},
#  {'City': 'Mount Pleasant',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:24:57',
#   'Humidity': 95,
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 75.18,
#   'Wind Speed': 5.01},
#  {'City': 'Bangaon',
#   'Cloudiness': 45,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:28:32',
#   'Humidity': 83,
#   'Lat': 23.0667,
#   'Lng': 88.8167,
#   'Max Temp': 76.95,
#   'Wind Speed': 7.29},
#  {'City': 'Salvador',
#   'Cloudiness': 73,
#   'Country': 'SV',
#   'Date': '2021-10-29 01:26:32',
#   'Humidity': 97,
#   'Lat': 13.8333,
#   'Lng': -88.9167,
#   'Max Temp': 70.2,
#   'Wind Speed': 2.06},
#  {'City': 'Rio Grande',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:23:36',
#   'Humidity': 87,
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 67.95,
#   'Wind Speed': 14.41},
#  {'City': 'Dikson',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:33',
#   'Humidity': 88,
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 9.03,
#   'Wind Speed': 5.1},
#  {'City': 'Cape Town',
#   'Cloudiness': 40,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:28:33',
#   'Humidity': 69,
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 61.88,
#   'Wind Speed': 5.99},
#  {'City': 'Coracora',
#   'Cloudiness': 66,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:28:34',
#   'Humidity': 62,
#   'Lat': -15.0333,
#   'Lng': -73.7833,
#   'Max Temp': 53.28,
#   'Wind Speed': 1.95},
#  {'City': 'Ishigaki',
#   'Cloudiness': 20,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:28:35',
#   'Humidity': 61,
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 77.13,
#   'Wind Speed': 10.36},
#  {'City': 'Lahij',
#   'Cloudiness': 39,
#   'Country': 'YE',
#   'Date': '2021-10-29 01:28:35',
#   'Humidity': 37,
#   'Lat': 13.1667,
#   'Lng': 44.5833,
#   'Max Temp': 76.55,
#   'Wind Speed': 1.66},
#  {'City': 'Kuching',
#   'Cloudiness': 20,
#   'Country': 'MY',
#   'Date': '2021-10-29 01:28:36',
#   'Humidity': 78,
#   'Lat': 1.55,
#   'Lng': 110.3333,
#   'Max Temp': 82.62,
#   'Wind Speed': 2.3},
#  {'City': 'Bambous Virieux',
#   'Cloudiness': 20,
#   'Country': 'MU',
#   'Date': '2021-10-29 01:28:36',
#   'Humidity': 94,
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 74.21,
#   'Wind Speed': 6.91},
#  {'City': 'Jardim',
#   'Cloudiness': 2,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:28:36',
#   'Humidity': 65,
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 75.02,
#   'Wind Speed': 5.35},
#  {'City': 'Flin Flon',
#   'Cloudiness': 8,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:24:31',
#   'Humidity': 79,
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 39.22,
#   'Wind Speed': 5.99},
#  {'City': 'Ostersund',
#   'Cloudiness': 90,
#   'Country': 'SE',
#   'Date': '2021-10-29 01:28:37',
#   'Humidity': 93,
#   'Lat': 63.1792,
#   'Lng': 14.6357,
#   'Max Temp': 50.61,
#   'Wind Speed': 9.22},
#  {'City': 'Fare',
#   'Cloudiness': 91,
#   'Country': 'PF',
#   'Date': '2021-10-29 01:28:38',
#   'Humidity': 90,
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 76.68,
#   'Wind Speed': 12.57},
#  {'City': 'Madingou',
#   'Cloudiness': 67,
#   'Country': 'CG',
#   'Date': '2021-10-29 01:28:38',
#   'Humidity': 90,
#   'Lat': -4.1536,
#   'Lng': 13.55,
#   'Max Temp': 74.1,
#   'Wind Speed': 3.27},
#  {'City': 'Fortuna',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:39',
#   'Humidity': 69,
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 66.42,
#   'Wind Speed': 5.75},
#  {'City': 'Ambilobe',
#   'Cloudiness': 25,
#   'Country': 'MG',
#   'Date': '2021-10-29 01:28:39',
#   'Humidity': 92,
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 72.14,
#   'Wind Speed': 1.52},
#  {'City': 'Tommot',
#   'Cloudiness': 3,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:26:40',
#   'Humidity': 69,
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': 24.57,
#   'Wind Speed': 10.11},
#  {'City': 'Upernavik',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:28:40',
#   'Humidity': 57,
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 21.06,
#   'Wind Speed': 4.9},
#  {'City': 'Saint-Francois',
#   'Cloudiness': 0,
#   'Country': 'FR',
#   'Date': '2021-10-29 01:28:40',
#   'Humidity': 83,
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 50.68,
#   'Wind Speed': 2.3},
#  {'City': 'Karratha',
#   'Cloudiness': 5,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:28:41',
#   'Humidity': 26,
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 81.72,
#   'Wind Speed': 7.99},
#  {'City': 'Skjervoy',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': '2021-10-29 01:28:42',
#   'Humidity': 86,
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 43.59,
#   'Wind Speed': 9.01},
#  {'City': 'Ayagoz',
#   'Cloudiness': 88,
#   'Country': 'KZ',
#   'Date': '2021-10-29 01:28:42',
#   'Humidity': 92,
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 41.92,
#   'Wind Speed': 6.96},
#  {'City': 'Honiara',
#   'Cloudiness': 51,
#   'Country': 'SB',
#   'Date': '2021-10-29 01:28:43',
#   'Humidity': 70,
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 86.7,
#   'Wind Speed': 6.42},
#  {'City': 'Caraballeda',
#   'Cloudiness': 78,
#   'Country': 'VE',
#   'Date': '2021-10-29 01:28:43',
#   'Humidity': 100,
#   'Lat': 10.6112,
#   'Lng': -66.8522,
#   'Max Temp': 80.67,
#   'Wind Speed': 1.14},
#  {'City': 'Moose Factory',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:28:44',
#   'Humidity': 70,
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 42.8,
#   'Wind Speed': 6.91},
#  {'City': 'Port Alfred',
#   'Cloudiness': 100,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:28:44',
#   'Humidity': 90,
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 67.64,
#   'Wind Speed': 9.08},
#  {'City': 'Kapaa',
#   'Cloudiness': 75,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:44',
#   'Humidity': 87,
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.38,
#   'Wind Speed': 3},
#  {'City': 'San Patricio',
#   'Cloudiness': 0,
#   'Country': 'US',
#   'Date': '2021-10-29 01:28:45',
#   'Humidity': 29,
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 76.84,
#   'Wind Speed': 8.66},
#  {'City': 'Pimentel',
#   'Cloudiness': 74,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:28:45',
#   'Humidity': 85,
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 64.15,
#   'Wind Speed': 14.2},
#  {'City': 'Mombetsu',
#   'Cloudiness': 75,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:28:46',
#   'Humidity': 87,
#   'Lat': 44.3525,
#   'Lng': 143.3525,
#   'Max Temp': 48.85,
#   'Wind Speed': 18.41},
#  {'City': 'Eydhafushi',
#   'Cloudiness': 77,
#   'Country': 'MV',
#   'Date': '2021-10-29 01:28:42',
#   'Humidity': 77,
#   'Lat': 5.1033,
#   'Lng': 73.0708,
#   'Max Temp': 81.72,
#   'Wind Speed': 8.63},
#  {'City': 'Bairiki',
#   'Cloudiness': 20,
#   'Country': 'KI',
#   'Date': '2021-10-29 01:28:47',
#   'Humidity': 62,
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp': 87.8,
#   'Wind Speed': 10.36},
#  {'City': 'San Andres',
#   'Cloudiness': 75,
#   'Country': 'CO',
#   'Date': '2021-10-29 01:24:34',
#   'Humidity': 94,
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 80.62,
#   'Wind Speed': 2.3},
#  {'City': 'Aksarka',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:47',
#   'Humidity': 94,
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': 19.85,
#   'Wind Speed': 19.55},
#  {'City': 'Koumac',
#   'Cloudiness': 8,
#   'Country': 'NC',
#   'Date': '2021-10-29 01:27:06',
#   'Humidity': 68,
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 80.01,
#   'Wind Speed': 6.73},
#  {'City': 'Mossendjo',
#   'Cloudiness': 36,
#   'Country': 'CG',
#   'Date': '2021-10-29 01:28:48',
#   'Humidity': 100,
#   'Lat': -2.9506,
#   'Lng': 12.7261,
#   'Max Temp': 68.97,
#   'Wind Speed': 2.46},
#  {'City': 'Rio Gallegos',
#   'Cloudiness': 40,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:28:49',
#   'Humidity': 55,
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 59.05,
#   'Wind Speed': 5.75},
#  {'City': 'Hualmay',
#   'Cloudiness': 97,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:28:49',
#   'Humidity': 83,
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 64.06,
#   'Wind Speed': 9.19},
#  {'City': 'Okhotsk',
#   'Cloudiness': 93,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:50',
#   'Humidity': 81,
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 25.36,
#   'Wind Speed': 6.42},
#  {'City': 'Nome',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:24:25',
#   'Humidity': 74,
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 24.87,
#   'Wind Speed': 12.66},
#  {'City': 'Arraial Do Cabo',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:28:51',
#   'Humidity': 90,
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.42,
#   'Wind Speed': 17.05},
#  {'City': 'Szedres',
#   'Cloudiness': 32,
#   'Country': 'HU',
#   'Date': '2021-10-29 01:28:51',
#   'Humidity': 56,
#   'Lat': 46.4755,
#   'Lng': 18.6831,
#   'Max Temp': 43.83,
#   'Wind Speed': 3.53},
#  {'City': 'Kieta',
#   'Cloudiness': 40,
#   'Country': 'PG',
#   'Date': '2021-10-29 01:28:52',
#   'Humidity': 61,
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 86.25,
#   'Wind Speed': 5.26},
#  {'City': 'Birao',
#   'Cloudiness': 16,
#   'Country': 'CF',
#   'Date': '2021-10-29 01:28:52',
#   'Humidity': 43,
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 74.01,
#   'Wind Speed': 1.59},
#  {'City': 'Kamenka',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:28:53',
#   'Humidity': 97,
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 44.11,
#   'Wind Speed': 7.54},
#  {'City': 'Fairbanks',
#   'Cloudiness': 20,
#   'Country': 'US',
#   'Date': '2021-10-29 01:25:38',
#   'Humidity': 89,
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 26.56,
#   'Wind Speed': 0},
#  {'City': 'Saskylakh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:25:06',
#   'Humidity': 98,
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -5.8,
#   'Wind Speed': 7.81},
#  {'City': 'Lakes Entrance',
#   'Cloudiness': 4,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:28:53',
#   'Humidity': 48,
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 70.16,
#   'Wind Speed': 26.98},
#  {'City': 'Cherskiy',
#   'Cloudiness': 32,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:24:57',
#   'Humidity': 90,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -9.83,
#   'Wind Speed': 2.98},
#  {'City': 'Grindavik',
#   'Cloudiness': 0,
#   'Country': 'IS',
#   'Date': '2021-10-29 01:28:54',
#   'Humidity': 81,
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 43.27,
#   'Wind Speed': 20.71},
#  {'City': 'Port Elizabeth',
#   'Cloudiness': 0,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:25:03',
#   'Humidity': 94,
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 63.1,
#   'Wind Speed': 2.3},
#  {'City': 'Cabra',
#   'Cloudiness': 100,
#   'Country': 'ES',
#   'Date': '2021-10-29 01:28:55',
#   'Humidity': 57,
#   'Lat': 37.4725,
#   'Lng': -4.4421,
#   'Max Temp': 63.39,
#   'Wind Speed': 4.14},
#  {'City': 'Richards Bay',
#   'Cloudiness': 100,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:28:55',
#   'Humidity': 71,
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 66.81,
#   'Wind Speed': 14.88},
#  {'City': 'Ahipara',
#   'Cloudiness': 4,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:24:04',
#   'Humidity': 71,
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 64.38,
#   'Wind Speed': 11.34},
#  {'City': 'Culaba',
#   'Cloudiness': 5,
#   'Country': 'PH',
#   'Date': '2021-10-29 01:28:56',
#   'Humidity': 76,
#   'Lat': 11.6578,
#   'Lng': 124.5425,
#   'Max Temp': 82.18,
#   'Wind Speed': 6.11},
#  {'City': 'Te Anau',
#   'Cloudiness': 4,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:28:57',
#   'Humidity': 56,
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 64.8,
#   'Wind Speed': 1.34},
#  {'City': 'Mahebourg',
#   'Cloudiness': 20,
#   'Country': 'MU',
#   'Date': '2021-10-29 01:28:57',
#   'Humidity': 94,
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 74.25,
#   'Wind Speed': 6.91},
#  {'City': 'Salalah',
#   'Cloudiness': 20,
#   'Country': 'OM',
#   'Date': '2021-10-29 01:28:57',
#   'Humidity': 83,
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 75.29,
#   'Wind Speed': 4.61},
#  {'City': 'Sibolga',
#   'Cloudiness': 53,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:28:58',
#   'Humidity': 67,
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 81.72,
#   'Wind Speed': 0.45},
#  {'City': 'Redcar',
#   'Cloudiness': 100,
#   'Country': 'GB',
#   'Date': '2021-10-29 01:28:58',
#   'Humidity': 86,
#   'Lat': 54.6166,
#   'Lng': -1.06,
#   'Max Temp': 56.32,
#   'Wind Speed': 5.99},
#  {'City': 'Sikonge',
#   'Cloudiness': 86,
#   'Country': 'TZ',
#   'Date': '2021-10-29 01:28:59',
#   'Humidity': 50,
#   'Lat': -5.6333,
#   'Lng': 32.7667,
#   'Max Temp': 69.51,
#   'Wind Speed': 6.55},
#  {'City': 'Bonavista',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:28:59',
#   'Humidity': 74,
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 40.12,
#   'Wind Speed': 15.99},
#  {'City': 'Maniitsoq',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:25:59',
#   'Humidity': 84,
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 28.53,
#   'Wind Speed': 11.68},
#  {'City': 'Severo-Kurilsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:00',
#   'Humidity': 95,
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 43.21,
#   'Wind Speed': 8.3},
#  {'City': 'Kampot',
#   'Cloudiness': 66,
#   'Country': 'KH',
#   'Date': '2021-10-29 01:29:01',
#   'Humidity': 82,
#   'Lat': 10.6167,
#   'Lng': 104.1833,
#   'Max Temp': 84.25,
#   'Wind Speed': 4.83},
#  {'City': 'Omsukchan',
#   'Cloudiness': 13,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:01',
#   'Humidity': 89,
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': 15.85,
#   'Wind Speed': 5.35},
#  {'City': 'Muravlenko',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:02',
#   'Humidity': 97,
#   'Lat': 63.7898,
#   'Lng': 74.523,
#   'Max Temp': 29.12,
#   'Wind Speed': 14.52},
#  {'City': 'Enid',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:24:49',
#   'Humidity': 34,
#   'Lat': 36.3956,
#   'Lng': -97.8784,
#   'Max Temp': 61.14,
#   'Wind Speed': 11.01},
#  {'City': 'Tiksi',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:02',
#   'Humidity': 95,
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 11.34,
#   'Wind Speed': 5.14},
#  {'City': 'Puerto Ayacucho',
#   'Cloudiness': 100,
#   'Country': 'VE',
#   'Date': '2021-10-29 01:24:14',
#   'Humidity': 89,
#   'Lat': 5.6639,
#   'Lng': -67.6236,
#   'Max Temp': 75.78,
#   'Wind Speed': 4.5},
#  {'City': 'Ambon',
#   'Cloudiness': 40,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:29:03',
#   'Humidity': 62,
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 86.14,
#   'Wind Speed': 3.44},
#  {'City': 'Bogotol',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:04',
#   'Humidity': 52,
#   'Lat': 56.2078,
#   'Lng': 89.5342,
#   'Max Temp': 28.63,
#   'Wind Speed': 8.34},
#  {'City': 'Bilma',
#   'Cloudiness': 5,
#   'Country': 'NE',
#   'Date': '2021-10-29 01:24:55',
#   'Humidity': 19,
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 77.81,
#   'Wind Speed': 1.54},
#  {'City': 'Novyy Urgal',
#   'Cloudiness': 13,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:04',
#   'Humidity': 73,
#   'Lat': 51.0736,
#   'Lng': 132.5642,
#   'Max Temp': 36.54,
#   'Wind Speed': 0.4},
#  {'City': 'Grand Gaube',
#   'Cloudiness': 6,
#   'Country': 'MU',
#   'Date': '2021-10-29 01:29:05',
#   'Humidity': 74,
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 74.37,
#   'Wind Speed': 5.99},
#  {'City': 'Bom Jesus',
#   'Cloudiness': 0,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:29:05',
#   'Humidity': 40,
#   'Lat': -9.0744,
#   'Lng': -44.3586,
#   'Max Temp': 77.9,
#   'Wind Speed': 1.12},
#  {'City': 'Tautira',
#   'Cloudiness': 100,
#   'Country': 'PF',
#   'Date': '2021-10-29 01:29:06',
#   'Humidity': 87,
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 73.42,
#   'Wind Speed': 9.66},
#  {'City': 'Tongchuan',
#   'Cloudiness': 100,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:29:06',
#   'Humidity': 63,
#   'Lat': 35.0806,
#   'Lng': 109.0897,
#   'Max Temp': 56.16,
#   'Wind Speed': 0.49},
#  {'City': 'Coihaique',
#   'Cloudiness': 0,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:25:29',
#   'Humidity': 58,
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 55.35,
#   'Wind Speed': 3.44},
#  {'City': 'Ostrovnoy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:07',
#   'Humidity': 88,
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 28.89,
#   'Wind Speed': 20.51},
#  {'City': 'Pisco',
#   'Cloudiness': 0,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:29:08',
#   'Humidity': 88,
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 61.02,
#   'Wind Speed': 16.11},
#  {'City': 'Yumen',
#   'Cloudiness': 5,
#   'Country': 'CN',
#   'Date': '2021-10-29 01:28:50',
#   'Humidity': 35,
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 41.67,
#   'Wind Speed': 4.18},
#  {'City': 'Lompoc',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:29:08',
#   'Humidity': 67,
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 82.13,
#   'Wind Speed': 6.91},
#  {'City': 'Kenai',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:29:09',
#   'Humidity': 92,
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 35.02,
#   'Wind Speed': 10.36},
#  {'City': 'Macklin',
#   'Cloudiness': 100,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:29:09',
#   'Humidity': 30,
#   'Lat': 52.3334,
#   'Lng': -109.9348,
#   'Max Temp': 43.93,
#   'Wind Speed': 7.67},
#  {'City': 'Paamiut',
#   'Cloudiness': 100,
#   'Country': 'GL',
#   'Date': '2021-10-29 01:29:10',
#   'Humidity': 74,
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 33.49,
#   'Wind Speed': 12.57},
#  {'City': 'Nova Olimpia',
#   'Cloudiness': 100,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:29:11',
#   'Humidity': 92,
#   'Lat': -14.7972,
#   'Lng': -57.2881,
#   'Max Temp': 73.31,
#   'Wind Speed': 4.12},
#  {'City': 'Yellowknife',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:24:39',
#   'Humidity': 100,
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 32.41,
#   'Wind Speed': 4.61},
#  {'City': 'Bam',
#   'Cloudiness': 4,
#   'Country': 'IR',
#   'Date': '2021-10-29 01:29:12',
#   'Humidity': 29,
#   'Lat': 29.106,
#   'Lng': 58.357,
#   'Max Temp': 61.21,
#   'Wind Speed': 1.39},
#  {'City': 'Lubbock',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:29:12',
#   'Humidity': 31,
#   'Lat': 33.6001,
#   'Lng': -101.8338,
#   'Max Temp': 59.14,
#   'Wind Speed': 3},
#  {'City': 'Abu Samrah',
#   'Cloudiness': 94,
#   'Country': 'SY',
#   'Date': '2021-10-29 01:29:13',
#   'Humidity': 55,
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 62.71,
#   'Wind Speed': 5.48},
#  {'City': 'Yuzhno-Kurilsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:13',
#   'Humidity': 90,
#   'Lat': 44.0306,
#   'Lng': 145.8556,
#   'Max Temp': 47.64,
#   'Wind Speed': 38.25},
#  {'City': 'Machala',
#   'Cloudiness': 72,
#   'Country': 'EC',
#   'Date': '2021-10-29 01:29:14',
#   'Humidity': 83,
#   'Lat': -3.2667,
#   'Lng': -79.9667,
#   'Max Temp': 72.59,
#   'Wind Speed': 5.17},
#  {'City': 'Laguna',
#   'Cloudiness': 1,
#   'Country': 'US',
#   'Date': '2021-10-29 01:29:14',
#   'Humidity': 74,
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 72.1,
#   'Wind Speed': 0},
#  {'City': 'Pangkalanbuun',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:29:14',
#   'Humidity': 81,
#   'Lat': -2.6833,
#   'Lng': 111.6167,
#   'Max Temp': 79.72,
#   'Wind Speed': 2.15},
#  {'City': 'Chalisgaon',
#   'Cloudiness': 7,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:29:15',
#   'Humidity': 52,
#   'Lat': 20.4667,
#   'Lng': 75.0167,
#   'Max Temp': 64.85,
#   'Wind Speed': 5.64},
#  {'City': 'Bengkulu',
#   'Cloudiness': 42,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:25:51',
#   'Humidity': 76,
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 80.96,
#   'Wind Speed': 3.89},
#  {'City': 'Airai',
#   'Cloudiness': 87,
#   'Country': 'TL',
#   'Date': '2021-10-29 01:29:16',
#   'Humidity': 48,
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 76.01,
#   'Wind Speed': 2.19},
#  {'City': 'Nouadhibou',
#   'Cloudiness': 2,
#   'Country': 'MR',
#   'Date': '2021-10-29 01:29:16',
#   'Humidity': 77,
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 67.98,
#   'Wind Speed': 14.97},
#  {'City': 'Saint Anthony',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:29:17',
#   'Humidity': 93,
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 48.54,
#   'Wind Speed': 3},
#  {'City': 'Ribeira Grande',
#   'Cloudiness': 100,
#   'Country': 'PT',
#   'Date': '2021-10-29 01:29:17',
#   'Humidity': 91,
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.92,
#   'Wind Speed': 30.49},
#  {'City': 'Raudeberg',
#   'Cloudiness': 100,
#   'Country': 'NO',
#   'Date': '2021-10-29 01:29:18',
#   'Humidity': 95,
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 54.19,
#   'Wind Speed': 8.99},
#  {'City': 'Puerto Leguizamo',
#   'Cloudiness': 24,
#   'Country': 'CO',
#   'Date': '2021-10-29 01:25:59',
#   'Humidity': 97,
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 71.13,
#   'Wind Speed': 0.45},
#  {'City': 'La Ronge',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:29:19',
#   'Humidity': 65,
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 41.22,
#   'Wind Speed': 2.3},
#  {'City': 'Fort Nelson',
#   'Cloudiness': 75,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:29:19',
#   'Humidity': 93,
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 31.59,
#   'Wind Speed': 4.61},
#  {'City': 'Hervey Bay',
#   'Cloudiness': 98,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:29:20',
#   'Humidity': 71,
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 83.03,
#   'Wind Speed': 17.72},
#  {'City': 'Dzilam Gonzalez',
#   'Cloudiness': 100,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:29:20',
#   'Humidity': 64,
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 81.03,
#   'Wind Speed': 10.56},
#  {'City': 'Vao',
#   'Cloudiness': 100,
#   'Country': 'NC',
#   'Date': '2021-10-29 01:29:21',
#   'Humidity': 69,
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 71.58,
#   'Wind Speed': 12.8},
#  {'City': 'Doha',
#   'Cloudiness': 0,
#   'Country': 'QA',
#   'Date': '2021-10-29 01:24:54',
#   'Humidity': 76,
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 82.29,
#   'Wind Speed': 4.61},
#  {'City': 'Veshenskaya',
#   'Cloudiness': 79,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:29:21',
#   'Humidity': 94,
#   'Lat': 49.6303,
#   'Lng': 41.7334,
#   'Max Temp': 44.19,
# ...
#   'Wind Speed': 3},
#  {'City': 'Batagay',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:11',
#   'Humidity': 81,
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 14.4,
#   'Wind Speed': 3.91},
#  {'City': 'Panino',
#   'Cloudiness': 33,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:12',
#   'Humidity': 94,
#   'Lat': 51.6467,
#   'Lng': 40.1346,
#   'Max Temp': 44.37,
#   'Wind Speed': 9.69},
#  {'City': 'Muros',
#   'Cloudiness': 100,
#   'Country': 'ES',
#   'Date': '2021-10-29 01:31:12',
#   'Humidity': 93,
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 60.1,
#   'Wind Speed': 9.6},
#  {'City': 'Sao Jose Da Tapera',
#   'Cloudiness': 29,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:13',
#   'Humidity': 84,
#   'Lat': -9.5583,
#   'Lng': -37.3811,
#   'Max Temp': 71.22,
#   'Wind Speed': 5.06},
#  {'City': 'Zelenoborsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:13',
#   'Humidity': 86,
#   'Lat': 61.4669,
#   'Lng': 64.0333,
#   'Max Temp': 21.88,
#   'Wind Speed': 16.91},
#  {'City': 'Provideniya',
#   'Cloudiness': 90,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:14',
#   'Humidity': 73,
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 15.91,
#   'Wind Speed': 11.18},
#  {'City': 'Kushmurun',
#   'Cloudiness': 100,
#   'Country': 'KZ',
#   'Date': '2021-10-29 01:31:14',
#   'Humidity': 73,
#   'Lat': 52.4503,
#   'Lng': 64.6311,
#   'Max Temp': 36.64,
#   'Wind Speed': 15.46},
#  {'City': 'Camden',
#   'Cloudiness': 38,
#   'Country': 'US',
#   'Date': '2021-10-29 01:31:15',
#   'Humidity': 87,
#   'Lat': 39.7835,
#   'Lng': -74.9663,
#   'Max Temp': 57.88,
#   'Wind Speed': 1.99},
#  {'City': 'Moree',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:31:15',
#   'Humidity': 69,
#   'Lat': -29.4667,
#   'Lng': 149.85,
#   'Max Temp': 75.22,
#   'Wind Speed': 18.41},
#  {'City': 'Yarmouth',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:31:16',
#   'Humidity': 73,
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 53.71,
#   'Wind Speed': 18.01},
#  {'City': 'Tigre',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:31:16',
#   'Humidity': 53,
#   'Lat': -34.426,
#   'Lng': -58.5796,
#   'Max Temp': 78.75,
#   'Wind Speed': 13.8},
#  {'City': 'La Rioja',
#   'Cloudiness': 100,
#   'Country': 'ES',
#   'Date': '2021-10-29 01:28:01',
#   'Humidity': 50,
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 51.04,
#   'Wind Speed': 5.48},
#  {'City': 'Srednekolymsk',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:26:46',
#   'Humidity': 87,
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 3.56,
#   'Wind Speed': 0.78},
#  {'City': 'Belaya Gora',
#   'Cloudiness': 99,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:17',
#   'Humidity': 96,
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': 3.22,
#   'Wind Speed': 0.56},
#  {'City': 'Saint-Pierre',
#   'Cloudiness': 90,
#   'Country': 'RE',
#   'Date': '2021-10-29 01:31:18',
#   'Humidity': 77,
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 73.08,
#   'Wind Speed': 3.44},
#  {'City': 'Mayumba',
#   'Cloudiness': 100,
#   'Country': 'GA',
#   'Date': '2021-10-29 01:31:18',
#   'Humidity': 89,
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 76.01,
#   'Wind Speed': 6.4},
#  {'City': 'Albanel',
#   'Cloudiness': 0,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:31:19',
#   'Humidity': 75,
#   'Lat': 48.8832,
#   'Lng': -72.4487,
#   'Max Temp': 35.58,
#   'Wind Speed': 5.75},
#  {'City': 'Algiers',
#   'Cloudiness': 20,
#   'Country': 'DZ',
#   'Date': '2021-10-29 01:31:20',
#   'Humidity': 94,
#   'Lat': 36.7525,
#   'Lng': 3.042,
#   'Max Temp': 53.42,
#   'Wind Speed': 1.14},
#  {'City': 'Lata',
#   'Cloudiness': 100,
#   'Country': 'PT',
#   'Date': '2021-10-29 01:29:39',
#   'Humidity': 92,
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 62.92,
#   'Wind Speed': 6.93},
#  {'City': 'Gao',
#   'Cloudiness': 26,
#   'Country': 'ML',
#   'Date': '2021-10-29 01:29:37',
#   'Humidity': 24,
#   'Lat': 16.6362,
#   'Lng': 1.637,
#   'Max Temp': 85.96,
#   'Wind Speed': 7.25},
#  {'City': 'Plettenberg Bay',
#   'Cloudiness': 98,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:31:13',
#   'Humidity': 86,
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 63.64,
#   'Wind Speed': 10.56},
#  {'City': 'Dunedin',
#   'Cloudiness': 89,
#   'Country': 'NZ',
#   'Date': '2021-10-29 01:30:48',
#   'Humidity': 76,
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 58.15,
#   'Wind Speed': 3.87},
#  {'City': 'Kulu',
#   'Cloudiness': 2,
#   'Country': 'TR',
#   'Date': '2021-10-29 01:31:21',
#   'Humidity': 64,
#   'Lat': 39.0951,
#   'Lng': 33.0799,
#   'Max Temp': 44.76,
#   'Wind Speed': 7.96},
#  {'City': 'Glace Bay',
#   'Cloudiness': 90,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:31:21',
#   'Humidity': 78,
#   'Lat': 46.1969,
#   'Lng': -59.957,
#   'Max Temp': 47.98,
#   'Wind Speed': 7},
#  {'City': 'Burnie',
#   'Cloudiness': 100,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:31:22',
#   'Humidity': 82,
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 50.92,
#   'Wind Speed': 20.07},
#  {'City': 'Velizh',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:22',
#   'Humidity': 98,
#   'Lat': 55.6056,
#   'Lng': 31.1967,
#   'Max Temp': 49.37,
#   'Wind Speed': 7.05},
#  {'City': 'Termiz',
#   'Cloudiness': 0,
#   'Country': 'UZ',
#   'Date': '2021-10-29 01:31:23',
#   'Humidity': 75,
#   'Lat': 37.2242,
#   'Lng': 67.2783,
#   'Max Temp': 39.29,
#   'Wind Speed': 2.3},
#  {'City': 'Calceta',
#   'Cloudiness': 100,
#   'Country': 'EC',
#   'Date': '2021-10-29 01:31:23',
#   'Humidity': 69,
#   'Lat': -0.85,
#   'Lng': -80.1667,
#   'Max Temp': 75.11,
#   'Wind Speed': 4.05},
#  {'City': 'Merke',
#   'Cloudiness': 74,
#   'Country': 'KZ',
#   'Date': '2021-10-29 01:31:24',
#   'Humidity': 81,
#   'Lat': 42.8728,
#   'Lng': 73.1786,
#   'Max Temp': 45.16,
#   'Wind Speed': 2.13},
#  {'City': 'Deputatskiy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:26',
#   'Humidity': 95,
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 10.38,
#   'Wind Speed': 3.67},
#  {'City': 'North Bend',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:31:26',
#   'Humidity': 97,
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 60.85,
#   'Wind Speed': 5.75},
#  {'City': 'Camana',
#   'Cloudiness': 100,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:31:27',
#   'Humidity': 81,
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 65.89,
#   'Wind Speed': 6.2},
#  {'City': 'Lagoa',
#   'Cloudiness': 100,
#   'Country': 'PT',
#   'Date': '2021-10-29 01:31:27',
#   'Humidity': 91,
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 69.49,
#   'Wind Speed': 33.31},
#  {'City': 'Katsuura',
#   'Cloudiness': 76,
#   'Country': 'JP',
#   'Date': '2021-10-29 01:31:28',
#   'Humidity': 50,
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 62.71,
#   'Wind Speed': 23.53},
#  {'City': 'Beyneu',
#   'Cloudiness': 3,
#   'Country': 'KZ',
#   'Date': '2021-10-29 01:31:29',
#   'Humidity': 45,
#   'Lat': 45.3167,
#   'Lng': 55.2,
#   'Max Temp': 38.17,
#   'Wind Speed': 9.08},
#  {'City': 'Auki',
#   'Cloudiness': 56,
#   'Country': 'SB',
#   'Date': '2021-10-29 01:31:00',
#   'Humidity': 68,
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 85.77,
#   'Wind Speed': 4.94},
#  {'City': 'Gorom-Gorom',
#   'Cloudiness': 9,
#   'Country': 'BF',
#   'Date': '2021-10-29 01:31:30',
#   'Humidity': 34,
#   'Lat': 14.4439,
#   'Lng': -0.2361,
#   'Max Temp': 86.58,
#   'Wind Speed': 6.51},
#  {'City': 'Palanga',
#   'Cloudiness': 13,
#   'Country': 'LT',
#   'Date': '2021-10-29 01:28:33',
#   'Humidity': 100,
#   'Lat': 55.9175,
#   'Lng': 21.0686,
#   'Max Temp': 49.95,
#   'Wind Speed': 8.05},
#  {'City': 'Vidnoye',
#   'Cloudiness': 75,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:30',
#   'Humidity': 82,
#   'Lat': 55.5524,
#   'Lng': 37.7097,
#   'Max Temp': 45.05,
#   'Wind Speed': 4.47},
#  {'City': 'Oskaloosa',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:31:31',
#   'Humidity': 93,
#   'Lat': 41.2964,
#   'Lng': -92.6444,
#   'Max Temp': 49.41,
#   'Wind Speed': 21.85},
#  {'City': 'Biak',
#   'Cloudiness': 100,
#   'Country': 'ID',
#   'Date': '2021-10-29 01:27:13',
#   'Humidity': 62,
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 84.36,
#   'Wind Speed': 2.8},
#  {'City': 'Januaria',
#   'Cloudiness': 67,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:32',
#   'Humidity': 54,
#   'Lat': -15.4833,
#   'Lng': -44.3667,
#   'Max Temp': 77.36,
#   'Wind Speed': 6.08},
#  {'City': 'Samarai',
#   'Cloudiness': 11,
#   'Country': 'PG',
#   'Date': '2021-10-29 01:31:32',
#   'Humidity': 74,
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 84.74,
#   'Wind Speed': 11.32},
#  {'City': 'Shumskiy',
#   'Cloudiness': 9,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:33',
#   'Humidity': 77,
#   'Lat': 54.8318,
#   'Lng': 99.1328,
#   'Max Temp': 29.03,
#   'Wind Speed': 5.79},
#  {'City': 'Arman',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:33',
#   'Humidity': 95,
#   'Lat': 59.7,
#   'Lng': 150.1667,
#   'Max Temp': 29.16,
#   'Wind Speed': 2.19},
#  {'City': 'Aksarayskiy',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:34',
#   'Humidity': 85,
#   'Lat': 46.7924,
#   'Lng': 48.0119,
#   'Max Temp': 46.35,
#   'Wind Speed': 6.44},
#  {'City': 'Tezu',
#   'Cloudiness': 0,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:31:34',
#   'Humidity': 42,
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 74.73,
#   'Wind Speed': 0.54},
#  {'City': 'Jonesboro',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:26:52',
#   'Humidity': 100,
#   'Lat': 35.8423,
#   'Lng': -90.7043,
#   'Max Temp': 53.76,
#   'Wind Speed': 13},
#  {'City': 'Nueve De Julio',
#   'Cloudiness': 41,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:31:35',
#   'Humidity': 48,
#   'Lat': -35.4444,
#   'Lng': -60.8831,
#   'Max Temp': 77.72,
#   'Wind Speed': 17.43},
#  {'City': 'Excelsior Springs',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:30:00',
#   'Humidity': 95,
#   'Lat': 39.3392,
#   'Lng': -94.2261,
#   'Max Temp': 48.69,
#   'Wind Speed': 12.66},
#  {'City': 'Neuquen',
#   'Cloudiness': 0,
#   'Country': 'AR',
#   'Date': '2021-10-29 01:31:35',
#   'Humidity': 60,
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 69.69,
#   'Wind Speed': 5.75},
#  {'City': 'Sao Joao Da Barra',
#   'Cloudiness': 98,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:36',
#   'Humidity': 87,
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 72.77,
#   'Wind Speed': 8.84},
#  {'City': 'Zalesovo',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:36',
#   'Humidity': 79,
#   'Lat': 53.9939,
#   'Lng': 84.7431,
#   'Max Temp': 32.41,
#   'Wind Speed': 10.31},
#  {'City': 'Medea',
#   'Cloudiness': 27,
#   'Country': 'DZ',
#   'Date': '2021-10-29 01:31:37',
#   'Humidity': 67,
#   'Lat': 36.2642,
#   'Lng': 2.7539,
#   'Max Temp': 45.05,
#   'Wind Speed': 4.29},
#  {'City': 'Porec',
#   'Cloudiness': 26,
#   'Country': 'HR',
#   'Date': '2021-10-29 01:31:37',
#   'Humidity': 63,
#   'Lat': 45.2258,
#   'Lng': 13.5939,
#   'Max Temp': 51.37,
#   'Wind Speed': 3.69},
#  {'City': 'Havre-Saint-Pierre',
#   'Cloudiness': 1,
#   'Country': 'CA',
#   'Date': '2021-10-29 01:31:38',
#   'Humidity': 75,
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 44.6,
#   'Wind Speed': 5.75},
#  {'City': 'Cozumel',
#   'Cloudiness': 40,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:31:39',
#   'Humidity': 87,
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp': 82.99,
#   'Wind Speed': 1.99},
#  {'City': 'Pangody',
#   'Cloudiness': 100,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:39',
#   'Humidity': 97,
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 27.41,
#   'Wind Speed': 12.41},
#  {'City': 'Nushki',
#   'Cloudiness': 0,
#   'Country': 'PK',
#   'Date': '2021-10-29 01:31:40',
#   'Humidity': 24,
#   'Lat': 29.5542,
#   'Lng': 66.0215,
#   'Max Temp': 56.46,
#   'Wind Speed': 0.98},
#  {'City': 'Riyadh',
#   'Cloudiness': 100,
#   'Country': 'SA',
#   'Date': '2021-10-29 01:27:09',
#   'Humidity': 23,
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 71.74,
#   'Wind Speed': 9.42},
#  {'City': 'La Trinitaria',
#   'Cloudiness': 99,
#   'Country': 'MX',
#   'Date': '2021-10-29 01:31:40',
#   'Humidity': 90,
#   'Lat': 16.1167,
#   'Lng': -92.05,
#   'Max Temp': 59.99,
#   'Wind Speed': 4.32},
#  {'City': 'Chatrapur',
#   'Cloudiness': 45,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:31:41',
#   'Humidity': 79,
#   'Lat': 19.35,
#   'Lng': 84.9833,
#   'Max Temp': 76.86,
#   'Wind Speed': 8.16},
#  {'City': 'Broken Hill',
#   'Cloudiness': 75,
#   'Country': 'AU',
#   'Date': '2021-10-29 01:31:41',
#   'Humidity': 40,
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 67.71,
#   'Wind Speed': 10.36},
#  {'City': 'Kargasok',
#   'Cloudiness': 95,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:42',
#   'Humidity': 72,
#   'Lat': 59.0556,
#   'Lng': 80.8572,
#   'Max Temp': 32.88,
#   'Wind Speed': 15.79},
#  {'City': 'Arara',
#   'Cloudiness': 39,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:43',
#   'Humidity': 85,
#   'Lat': -6.8283,
#   'Lng': -35.7583,
#   'Max Temp': 68.59,
#   'Wind Speed': 10.33},
#  {'City': 'Natchitoches',
#   'Cloudiness': 90,
#   'Country': 'US',
#   'Date': '2021-10-29 01:31:43',
#   'Humidity': 59,
#   'Lat': 31.7668,
#   'Lng': -93.1335,
#   'Max Temp': 67.35,
#   'Wind Speed': 4.61},
#  {'City': 'Ipixuna',
#   'Cloudiness': 98,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:44',
#   'Humidity': 95,
#   'Lat': -1.7625,
#   'Lng': -48.8043,
#   'Max Temp': 76.95,
#   'Wind Speed': 4.18},
#  {'City': 'Floriano',
#   'Cloudiness': 57,
#   'Country': 'BR',
#   'Date': '2021-10-29 01:31:44',
#   'Humidity': 30,
#   'Lat': -6.7669,
#   'Lng': -43.0225,
#   'Max Temp': 86.05,
#   'Wind Speed': 4.45},
#  {'City': 'Phan Thiet',
#   'Cloudiness': 96,
#   'Country': 'VN',
#   'Date': '2021-10-29 01:30:38',
#   'Humidity': 73,
#   'Lat': 10.9333,
#   'Lng': 108.1,
#   'Max Temp': 82.36,
#   'Wind Speed': 2.39},
#  {'City': 'Seymchan',
#   'Cloudiness': 94,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:45',
#   'Humidity': 81,
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': 13.46,
#   'Wind Speed': 4.43},
#  {'City': 'Upata',
#   'Cloudiness': 100,
#   'Country': 'VE',
#   'Date': '2021-10-29 01:31:45',
#   'Humidity': 95,
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 71.29,
#   'Wind Speed': 3.11},
#  {'City': 'Esso',
#   'Cloudiness': 42,
#   'Country': 'RU',
#   'Date': '2021-10-29 01:31:46',
#   'Humidity': 91,
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp': 32.49,
#   'Wind Speed': 3.27},
#  {'City': 'Yuli',
#   'Cloudiness': 66,
#   'Country': 'NG',
#   'Date': '2021-10-29 01:31:46',
#   'Humidity': 71,
#   'Lat': 9.6989,
#   'Lng': 10.2744,
#   'Max Temp': 75.51,
#   'Wind Speed': 2.21},
#  {'City': 'Wanlaweyn',
#   'Cloudiness': 26,
#   'Country': 'SO',
#   'Date': '2021-10-29 01:31:47',
#   'Humidity': 82,
#   'Lat': 2.6185,
#   'Lng': 44.8938,
#   'Max Temp': 75.4,
#   'Wind Speed': 4.79},
#  {'City': 'Huarmey',
#   'Cloudiness': 87,
#   'Country': 'PE',
#   'Date': '2021-10-29 01:31:47',
#   'Humidity': 85,
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 64.26,
#   'Wind Speed': 9.01},
#  {'City': 'Mavelikara',
#   'Cloudiness': 100,
#   'Country': 'IN',
#   'Date': '2021-10-29 01:31:48',
#   'Humidity': 90,
#   'Lat': 9.2667,
#   'Lng': 76.55,
#   'Max Temp': 76.1,
#   'Wind Speed': 1.9},
#  {'City': 'Savannah Bight',
#   'Cloudiness': 16,
#   'Country': 'HN',
#   'Date': '2021-10-29 01:31:48',
#   'Humidity': 79,
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 84,
#   'Wind Speed': 10.22},
#  {'City': 'Vryburg',
#   'Cloudiness': 89,
#   'Country': 'ZA',
#   'Date': '2021-10-29 01:31:49',
#   'Humidity': 81,
#   'Lat': -26.9566,
#   'Lng': 24.7284,
#   'Max Temp': 62.01,
#   'Wind Speed': 13.4},
#  {'City': 'Challapata',
#   'Cloudiness': 55,
#   'Country': 'BO',
#   'Date': '2021-10-29 01:31:49',
#   'Humidity': 49,
#   'Lat': -18.9,
#   'Lng': -66.7667,
#   'Max Temp': 52.23,
#   'Wind Speed': 5.68},
#  {'City': 'Vallenar',
#   'Cloudiness': 47,
#   'Country': 'CL',
#   'Date': '2021-10-29 01:31:50',
#   'Humidity': 48,
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 67.41,
#   'Wind Speed': 1.43},
#  {'City': 'Kandiari',
#   'Cloudiness': 0,
#   'Country': 'PK',
#   'Date': '2021-10-29 01:31:50',
#   'Humidity': 26,
#   'Lat': 26.9156,
#   'Lng': 68.5216,
#   'Max Temp': 75.11,
#   'Wind Speed': 3.58},
#  {'City': 'Los Dos Caminos',
#   'Cloudiness': 57,
#   'Country': 'VE',
#   'Date': '2021-10-29 01:31:51',
#   'Humidity': 96,
#   'Lat': 10.4939,
#   'Lng': -66.8286,
#   'Max Temp': 70.92,
#   'Wind Speed': 2.51},
#  {'City': 'Bras-Panon',
#   'Cloudiness': 45,
#   'Country': 'RE',
#   'Date': '2021-10-29 01:31:51',
#   'Humidity': 99,
#   'Lat': -20.9967,
#   'Lng': 55.6782,
#   'Max Temp': 73.06,
#   'Wind Speed': 16.04}]

# %%
#Add the data to a list in a dictionary format and then convert the list to a DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed"]

#assign city_data_df with new column order
city_data_df = city_data_df[new_column_order]


# Display DataFrame
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        New Norfolk      AU -42.7826  147.0587     45.91        79
# 1       Punta Arenas      CL -53.1500  -70.9167     53.71        66
# 2            Mataura      NZ -46.1927  168.8643     71.55        45
# 3        East London      ZA -33.0153   27.9116     66.34        96
# 4        Forestville      US  38.8451  -76.8750     61.30        80
# ..               ...     ...      ...       ...       ...       ...
# 554       Challapata      BO -18.9000  -66.7667     52.23        49
# 555         Vallenar      CL -28.5708  -70.7581     67.41        48
# 556         Kandiari      PK  26.9156   68.5216     75.11        26
# 557  Los Dos Caminos      VE  10.4939  -66.8286     70.92        96
# 558       Bras-Panon      RE -20.9967   55.6782     73.06        99
#
#      Cloudiness  Wind Speed
# 0           100        7.00
# 1            75       16.11
# 2            19        0.96
# 3           100        8.21
# 4            90        9.22
# ..          ...         ...
# 554          55        5.68
# 555          47        1.43
# 556           0        3.58
# 557          57        2.51
# 558          45       16.04
#
# [559 rows x 8 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
